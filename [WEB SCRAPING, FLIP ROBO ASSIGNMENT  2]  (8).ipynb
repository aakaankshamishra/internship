# %% [markdown]
# # 1) Write a python program to display all the header tags from wikipedia.org

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import  requests
from  bs4 import BeautifulSoup

url = requests.get('https://en.wikipedia.org/wiki/Main_Page')
soup = BeautifulSoup(url.text, 'html.parser')
story = soup.find_all(['h1', 'h2','h3'])
for i in story:
    print(i)
# Out:
# <h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none">Main Page</h1>
# <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
# ...

# %% [markdown]
# # 2) Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release)
# and make data frame.

# %%
print(len(Name),len(Rating),len(Year))
# Out:
# 50 50 50

# %%
import pandas as pd
df=pd.DataFrame({'Name':Name,'Rating':Rating,'Year':Year})
df
# Out:
#                                                  Name  \
# 0            \n1.\nThe Shawshank Redemption\n(1994)\n
# 1                       \n2.\nThe Godfather\n(1972)\n
# 2                     \n3.\nThe Dark Knight\n(2008)\n
# 3   \n4.\nThe Lord of the Rings: The Return of the...
# 4                    \n5.\nSchindler's List\n(1993)\n
# 5              \n6.\nThe Godfather: Part II\n(1974)\n
# 6                        \n7.\n12 Angry Men\n(1957)\n
# 7                        \n8.\nPulp Fiction\n(1994)\n
# 8   \n9.\nEverything Everywhere All at Once\n(2022)\n
# 9                          \n10.\nInception\n(2010)\n
# 10  \n11.\nThe Lord of the Rings: The Two Towers\n...
# 11                        \n12.\nFight Club\n(1999)\n
# 12  \n13.\nThe Lord of the Rings: The Fellowship o...
# 13                      \n14.\nForrest Gump\n(1994)\n
# 14   \n15.\nIl buono, il brutto, il cattivo\n(1966)\n
# 15                        \n16.\nThe Matrix\n(1999)\n
# ...

# %% [markdown]
# # 3) Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. name, rating, year of
# release) and make data frame.

# %%
print(len(Name),len(Rating),len(Year))
# Out:
# 250 250 250

# %%
import pandas as pd
df=pd.DataFrame({'Name':Name,'Rating':Rating,'Year':Year})
df
# Out:
#                                                Name   Rating    Year
# 0              \n      1.\n      Jai Bhim\n(2021)\n  \n8.4\n  (2021)
# 1            \n      2.\n      Anbe Sivam\n(2003)\n  \n8.4\n  (2003)
# 2               \n      3.\n      Golmaal\n(1979)\n  \n8.4\n  (1979)
# 3               \n      4.\n      Nayakan\n(1987)\n  \n8.4\n  (1987)
# 4     \n      5.\n      Pariyerum Perumal\n(2018)\n  \n8.4\n  (2018)
# ..                                              ...      ...     ...
# 245              \n      246.\n      Arya\n(2004)\n  \n7.6\n  (2004)
# 246           \n      247.\n      Samsara\n(2001)\n  \n7.6\n  (2001)
# 247              \n      248.\n      Eega\n(2012)\n  \n7.6\n  (2012)
# 248            \n      249.\n      Newton\n(2017)\n  \n7.6\n  (2017)
# 249  \n      250.\n      Mumbai Meri Jaan\n(2008)\n  \n7.6\n  (2008)
#
# [250 rows x 3 columns]

# %% [markdown]
# # 4) Write a python program to scrape product name, price and discounts from https://meesho.com/bagsladies/pl/p7vbp .

# %%
print(len(Product_name),len(Discount),len(Price))
# Out:
# 16 16 16

# %%
# making dataframe
import pandas as pd
df=pd.DataFrame({'Product_name':Product_name,'Discount':Discount,'Price':Price})
df
# Out:
#                             Product_name                   Discount  \
# 0        Ravishing Classy Women Handbags  ₹50 discount on 1st order
# 1          Graceful Fancy Women Handbags  ₹50 discount on 1st order
# 2       Classic Versatile Women Handbags  ₹50 discount on 1st order
# 3           Voguish Fancy Women Handbags  ₹50 discount on 1st order
# 4      Ravishing Alluring Women Handbags  ₹50 discount on 1st order
# 5   Ravishing Fashionable Women Handbags  ₹50 discount on 1st order
# 6         Classic Stylish Women Handbags  ₹50 discount on 1st order
# 7      Graceful Versatile Women Handbags  ₹50 discount on 1st order
# 8          Elegant Classy Women Handbags  ₹50 discount on 1st order
# 9        Elegant Alluring Women Handbags  ₹50 discount on 1st order
# 10        Trendy Alluring Women Handbags  ₹50 discount on 1st order
# 11    Elegant Fashionable Women Handbags  ₹50 discount on 1st order
# 12       Classic Alluring Women Handbags  ₹50 discount on 1st order
# ...

# %% [markdown]
# # 5) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
# b) Top 10 ODI Batsmen along with the records of their team and rating.
# c) Top 10 ODI bowlers along with the records of their team and rating.

# %% [markdown]
# # a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating

# %%
pip install requests
# Out:
# ...
#
# ...

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')

# %%
page
# Out:
# <Response [200]>

# %%
Soup = BeautifulSoup(page.content)

# %%
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
matches  = Soup.find('th',class_='table-head__cell u-center-text')
matches
# Out:
# <th class="table-head__cell u-center-text">
# <span class="u-hide-mobile">Matches</span>
# <span class="u-show-mobile">M</span>
# </th>

# %%
matches.text
# Out:
# '\nMatches\nM\n'

# %%
matches = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell u-center-text"):
    matches.append(i.text)
    
matches
# Out:
# ['\nMatches\nM\n', '\nPoints\nP\n']

# %%
points = Soup.find('th',class_='table-head__cell u-center-text')
points
# Out:
# <th class="table-head__cell u-center-text">
# <span class="u-hide-mobile">Matches</span>
# <span class="u-show-mobile">M</span>
# </th>

# %%
points.text
# Out:
# '\nMatches\nM\n'

# %%
points = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell u-center-text"):
    points.append(i.text)
    
points
# Out:
# ['\nMatches\nM\n', '\nPoints\nP\n']

# %%
ratings = Soup.find('th',class_="table-head__cell u-text-right rating")
ratings
# Out:
# <th class="table-head__cell u-text-right rating">
# <span class="u-hide-mobile">Rating</span>
# <span class="u-show-mobile">R</span>
# </th>

# %%
ratings.text
# Out:
# '\nRating\nR\n'

# %%
ratings = [] #empty 
for i in Soup.find_all('th',class_="table-head__cell u-text-right rating"):
    ratings.append(i.text)
ratings
# Out:
# ['\nRating\nR\n']

# %% [markdown]
# # b) Top 10 ODI Batsmen along with the records of their team and rating.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi')

# %%
page
# Out:
# <Response [200]>

# %%
Soup = BeautifulSoup(page.content)

# %%
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Player Rankings | ICC" property="og:title"/>
# ...

# %%
player = Soup.find('th',class_="table-head__cell")
player
# Out:
# <th class="table-head__cell u-text-center">Pos</th>

# %%
player.text
# Out:
# 'Pos'

# %%
player = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell"):
    player.append(i.text)

    
player
# Out:
# ['Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating']

# %%
team = Soup.find('th',class_="table-head__cell")
team
# Out:
# <th class="table-head__cell u-text-center">Pos</th>

# %%
team.text
# Out:
# 'Pos'

# %%
team = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell"):
    team.append(i.text)

    
team
# Out:
# ['Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating']

# %%
rating = Soup.find('th',class_="table-head__cell u-text-right")
rating
# Out:
# <th class="table-head__cell u-text-right">Rating</th>

# %%
rating.text
# Out:
# 'Rating'

# %%
rating = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell u-text-right"):
    rating.append(i.text)

    
rating
# Out:
# ['Rating', 'Rating', 'Rating', 'Rating', 'Rating', 'Rating']

# %%
print(len(team),len(rating),len(player))
# Out:
# 24 6 24

# %%
# making dataframe
import pandas as pd
df=pd.DataFrame({'team':team,'player':player})
df
# Out:
#       team  player
# 0      Pos     Pos
# 1   Player  Player
# 2     Team    Team
# 3   Rating  Rating
# 4      Pos     Pos
# 5   Player  Player
# 6     Team    Team
# 7   Rating  Rating
# 8      Pos     Pos
# 9   Player  Player
# 10    Team    Team
# 11  Rating  Rating
# 12     Pos     Pos
# 13  Player  Player
# 14    Team    Team
# 15  Rating  Rating
# 16     Pos     Pos
# 17  Player  Player
# 18    Team    Team
# 19  Rating  Rating
# 20     Pos     Pos
# 21  Player  Player
# 22    Team    Team
# 23  Rating  Rating

# %% [markdown]
# # c) Top 10 ODI bowlers along with the records of their team and rating.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi')

# %%
page
# Out:
# <Response [200]>

# %%
Soup = BeautifulSoup(page.content)

# %%
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Player Rankings | ICC" property="og:title"/>
# ...

# %% [markdown]
# # TEAM

# %%
team = Soup.find('th',class_="table-head__cell")
team
# Out:
# <th class="table-head__cell u-text-center">Pos</th>

# %%
team.text
# Out:
# 'Pos'

# %%
team = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell"):
    team.append(i.text)
    
team
# Out:
# ['Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating']

# %% [markdown]
# # RATING

# %%
rating = Soup.find('th',class_="table-head__cell u-text-right")
rating
# Out:
# <th class="table-head__cell u-text-right">Rating</th>

# %%
rating.text
# Out:
# 'Rating'

# %%
ratings = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell u-text-right"):
    ratings.append(i.text)
    
ratings
# Out:
# ['Rating', 'Rating', 'Rating', 'Rating', 'Rating', 'Rating']

# %%
print(len(team),len(ratings))
# Out:
# 24 6

# %% [markdown]
# # 6) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating

# %% [markdown]
# # a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')

# %%
page
# Out:
# <Response [200]>

# %%
Soup = BeautifulSoup(page.content)

# %%
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %% [markdown]
# # MATCHES

# %%
MATCHES = Soup.find('span',class_='u-hide-mobile')
MATCHES
# Out:
# <span class="u-hide-mobile">Team</span>

# %%
MATCHES.text
# Out:
# 'Team'

# %%
MATCHES = [] #empty list
for i in Soup.find_all('span',class_="u-hide-mobile"):
    MATCHES.append(i.text)
    
MATCHES
# Out:
# ['Team', 'Matches', 'Points', 'Rating']

# %% [markdown]
# # POINTS

# %%
points = Soup.find('th',class_='table-head__cell u-center-text')
points
# Out:
# <th class="table-head__cell u-center-text">
# <span class="u-hide-mobile">Matches</span>
# <span class="u-show-mobile">M</span>
# </th>

# %%
points.text
# Out:
# '\nMatches\nM\n'

# %%
points = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell u-center-text"):
    points.append(i.text)
    
points
# Out:
# ['\nMatches\nM\n', '\nPoints\nP\n']

# %% [markdown]
# # RATING

# %%
ratings = Soup.find('th',class_='table-head__cell u-text-right rating')
ratings
# Out:
# <th class="table-head__cell u-text-right rating">
# <span class="u-hide-mobile">Rating</span>
# <span class="u-show-mobile">R</span>
# </th>

# %%
ratings.text
# Out:
# '\nRating\nR\n'

# %%
ratings = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell u-text-right rating"):
    ratings.append(i.text)
    
ratings
# Out:
# ['\nRating\nR\n']

# %%
print(len(MATCHES),len(points),len(ratings))
# Out:
# 2 2 1

# %% [markdown]
# # b) Top 10 women’s ODI Batting players along with the records of their team and rating.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
page = requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi')

# %%
page
# Out:
# <Response [200]>

# %%
Soup = BeautifulSoup(page.content)

# %%
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Player Rankings | ICC" property="og:title"/>
# ...

# %% [markdown]
# # TEAM

# %%
TEAM = Soup.find('th',class_="table-head__cell")
TEAM
# Out:
# <th class="table-head__cell u-text-center">Pos</th>

# %%
TEAM.text
# Out:
# 'Pos'

# %%
TEAM = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell"):
    TEAM.append(i.text)
    
TEAM
# Out:
# ['Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating',
#  'Pos',
#  'Player',
#  'Team',
#  'Rating']

# %% [markdown]
# # RATING

# %%
rating = Soup.find('th',class_="table-head__cell u-text-right")
rating
# Out:
# <th class="table-head__cell u-text-right">Rating</th>

# %%
rating.text
# Out:
# 'Rating'

# %%
rating = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell u-text-right"):
    rating.append(i.text)
    
rating
# Out:
# ['Rating', 'Rating', 'Rating']

# %% [markdown]
# # c) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')

# %%
page
# Out:
# <Response [200]>

# %%
Soup = BeautifulSoup(page.content)

# %%
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI All Rounder | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI All Rounder | Player Rankings | ICC" property="og:title"/>
# ...

# %% [markdown]
# # TEAM

# %%
 team = Soup.find('th',class_='table-head__cell')
 team
# Out:
# <th class="table-head__cell u-text-right">Pos</th>

# %%
team.text
# Out:
# 'Pos'

# %%
team = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell"):
    team.append(i.text)
    
team
# Out:
# ['Pos', 'Player', 'Team', 'Rating', 'Career Best Rating']

# %% [markdown]
# # RATING

# %%
rating = Soup.find('th',class_='table-head__cell table-head__cell--rating')
rating
# Out:
# <th class="table-head__cell table-head__cell--rating">Rating</th>

# %%
rating.text
# Out:
# 'Rating'

# %%
rating = [] #empty list
for i in Soup.find_all('th',class_="table-head__cell table-head__cell--rating"):
    rating.append(i.text)
    
rating
# Out:
# ['Rating']

# %%
print(len(team),len(rating))
# Out:
# 5 1

# %% [markdown]
# # 7) Write a python program to scrape details of all the posts from coreyms.com. Scrape the heading, date, content
# and the code for the video from the link for the youtube video from the post

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
page = requests.get('https://coreyms.com/development/python/python-tutorial-csv-module-read-parse-write-csv-fileS')

# %%
page
# Out:
# <Response [200]>

# %%
Soup = BeautifulSoup(page.content)

# %%
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- This site is optimized with the Yoast SEO plugin v15.4 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>Python Tutorial: CSV Module - How to Read, Parse, and Write CSV Files - CoreyMS</title>
# <meta content="In this Python Programming Tutorial, we will be learning how to work with csv files using the csv module. We will learn how to read, parse, and write to" name="description"/>
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <link href="https://coreyms.com/development/python/python-tutorial-csv-module-read-parse-write-csv-files" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="Python Tutorial: CSV Module - How to Read, Parse, and Write CSV Files - CoreyMS" property="og:title"/>
# ...

# %%
heading = Soup.find('h1',class_="entry-title")
heading
# Out:
# <h1 class="entry-title" itemprop="headline">Python Tutorial: CSV Module – How to Read, Parse, and Write CSV Files</h1>

# %%
heading = [] #empty list
for i in Soup.find_all('h1',class_="entry-title"):
    heading.append(i.text)

    
heading
# Out:
# ['Python Tutorial: CSV Module – How to Read, Parse, and Write CSV Files']

# %%
date = Soup.find('p',class_="entry-meta")
date
# Out:
# <p class="entry-meta"><time class="entry-time" datetime="2017-08-09T13:11:31-04:00" itemprop="datePublished">August 9, 2017</time> by <span class="entry-author" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><a class="entry-author-link" href="https://coreyms.com/author/coreymschafer" itemprop="url" rel="author"><span class="entry-author-name" itemprop="name">Corey Schafer</span></a></span> <span class="entry-comments-link"><a href="https://coreyms.com/development/python/python-tutorial-csv-module-read-parse-write-csv-files#comments"><span class="dsq-postid" data-dsqidentifier="1383 http://coreyms.com/?p=1383">1 Comment</span></a></span> </p>

# %%
date = [] #empty list
for i in Soup.find_all('p',class_="entry-meta"):
    date.append(i.text)

    
date
# Out:
# ['August 9, 2017 by Corey Schafer 1 Comment ',
#  'Filed Under: Development, Python Tagged With: CSV, Programming, Video']

# %% [markdown]
# # 8) Write a python program to scrape house details from mentioned URL. It should include house title, location,
# area, EMI and price from https://www.nobroker.in/ .Enter three localities which are Indira Nagar, Jayanagar,
# Rajaji Nagar.

# %%
# making dataframe
import pandas as pd
df=pd.DataFrame({'HOUSE_TITLE':HOUSE_TITLE,'LOCATION':LOCATION,'AREA':AREA,'EMI':EMI,'PRICE':PRICE})
df
# Out:
#                                           HOUSE_TITLE  \
# 0                  2 BHK Flat  For Rent  In Yelahanka
# 1   2 BHK In Independent House  For Rent  In Gayat...
# 2   2 BHK Flat  For Rent  In Stand Alone  Building...
# 3                2 BHK Flat  For Rent  In Indiranagar
# 4                  4 BHK Flat  For Rent  In Jayanagar
# 5   2 BHK For Rent  In Guru Prasanna In Jayanagar 1st
# 6   2 BHK Flat  For Rent  In Shanthi Park Apartmen...
# 7   2 BHK Flat  For Rent  In Stand Alone Building ...
# 8               3 BHK Flat  For Rent  In Vijaya Nagar
# 9   2 BHK Apartment  For Rent  In Adarsh Palace In...
# 10                 3 BHK Flat  For Rent  In Jayanagar
# 11  1 BHK Flat  For Rent  In Khb Colony Jayanagar ...
# 12  3 BHK In Independent House  For Rent  In Jayan...
# 13  2 BHK In Independent House  For Rent  In Jayan...
# 14  2 BHK In Independent House  For Rent  In Jayan...
# 15  2 BHK Flat  For Rent  In Sree Rama Nilaya In B...
# ...

# %% [markdown]
# # 9) Write a python program to scrape mentioned details from dineout.co.in :
# i) Restaurant name
# ii) Cuisine
# iii) Location
# iv) Ratings
# v) Image URL

# %%
import pandas as pd
df=pd.DataFrame({'Restaurant_name':Restaurant_name,'cuisine':cuisine,'location':loc,'rating':rating,'images':images})
df
# Out:
#                                       Restaurant_name  \
# 0               TamashaConnaught Place, Central Delhi
# 1   LocalScindia House,Connaught Place, Central Delhi
# 2   Unplugged CourtyardConnaught Place, Central Delhi
# 3   The G.T. ROADM-Block,Connaught Place, Central ...
# 4   Ministry Of BeerM-Block,Connaught Place, Centr...
# 5   Connaught Clubhouse MicrobreweryConnaught Plac...
# 6     The Junkyard CafeConnaught Place, Central Delhi
# 7        Openhouse CafeConnaught Place, Central Delhi
# 8        Warehouse CafeConnaught Place, Central Delhi
# 9   Chili's American Grill and BarM-Block,Connaugh...
# 10  High 5 - Everyday Wholesale BarConnaught Place...
# 11                  QBAConnaught Place, Central Delhi
# 12              Berco'sConnaught Place, Central Delhi
# 13   Lord of the DrinksConnaught Place, Central Delhi
# 14               SandozConnaught Place, Central Delhi
# 15                ChidoConnaught Place, Central Delhi
# ...

# %% [markdown]
# # 10) Write a python program to scrape first 10 product details which include product name , price , Image URL from
# https://www.bewakoof.com/women-tshirts?ga_q=tshirts .

# %%
import pandas as pd
df=pd.DataFrame({'name':name,'price':price,'image':images})
df
# Out:
#                                                 name  price image
# 0  Women's White Striped Top₹ 5291299₹499For TriB...  ₹ 529    []
# 1  Women's Blue Printed Top₹ 4991299₹469For TriBe...  ₹ 499    []
# 2  Women's Blue Floral Print Dress₹ 6991499₹659Fo...  ₹ 699    []
# 3  Nude Puff Sleeve Women's Fitted Crop Top₹ 6491...  ₹ 649    []
# 4  Women's Yellow Solid Top₹ 4991299₹469For TriBe...  ₹ 499    []
# 5   White Regular Top₹ 6081299₹569For TriBe Members   ₹ 608    []
# 6  Women's Yellow Striped Puff Sleeve Crepe Cinch...  ₹ 629    []
# 7  Slumber Jill Women Pyjama (Pack of 1)₹ 419699F...  ₹ 419    []
# 8  Slumber Jill Pack of 2 Lounge Pants - AOP Snow...  ₹ 649    []
# 9  Women's Blue Solid T-shirt₹ 4551199FEW LEFT₹42...  ₹ 455    []
